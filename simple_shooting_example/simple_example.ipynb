# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # example 1
#
# ![image.png](attachment:image.png)
#
# $N = 2$ we have 1 initial value and 1 boundary value for $x_1$

# %%
def dx1dt():
    return x2


def dx2dt():
    return 2*x1**3-6*x1-2*t**3

# %%
def RHS():
    return []
